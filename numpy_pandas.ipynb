# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "Maths" : [85, 78, 92],
    "Science" : [90, 82, 88],
})
arr = df.values
print(arr)
# Out:
# [[85 90]
#  [78 82]
#  [92 88]]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr.shape)
# Out:
# (3, 2)

# %%
x = df[["Maths","Science"]].to_numpy()
print(x.shape)
# Out:
# (3, 2)

# %%
s = pd.Series(np.array([1, 2, 3]),name = "Values")
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# Name: Values, dtype: int64

# %%
arr2d = np.array([[1, 2],[3, 4], [5, 6]])
df2 = pd.DataFrame(arr2d, columns=["A", "B"])
print(df2)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6

# %%
print(type(df2))
# Out:
# <class 'pandas.DataFrame'>
